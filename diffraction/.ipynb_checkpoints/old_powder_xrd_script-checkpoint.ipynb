# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

nickel = {
    '2θ (degrees)' : [44.47, 51.88, 76.45]
    'intensity' : [86664, 97260, 98732]
}
hhgm_al = {
    '2θ (degrees)' = [38.5,45.01,65.17,78.31]
    'intensity' : [88549, 94191, 77714, 96400]
}
nacl = {
    'Q (1/A)' = [2.27158,3.16287,4.47829,4.99938]
    'intensity' = [88008, 19140, 98858, 46248]
}

df_ni = pd.DataFrame(nickel)
df_al = pd.DataFrame(hhgm_al)
df_nacl = pd.DataFrame(nacl)

df_ni
# Out:
#   Cell In[1], line 6
#     '2θ (degrees)' : [44.47, 51.88, 76.45]
#                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

nickel = {
    '2θ (degrees)' : [44.47, 51.88, 76.45],
    'intensity' : [86664, 97260, 98732]
}
hhgm_al = {
    '2θ (degrees)' = [38.5,45.01,65.17,78.31],
    'intensity' : [88549, 94191, 77714, 96400]
}
nacl = {
    'Q (1/A)' = [2.27158,3.16287,4.47829,4.99938],
    'intensity' = [88008, 19140, 98858, 46248]
}

df_ni = pd.DataFrame(nickel)
df_al = pd.DataFrame(hhgm_al)
df_nacl = pd.DataFrame(nacl)

df_ni
# Out:
#   Cell In[2], line 10
#     '2θ (degrees)' = [38.5,45.01,65.17,78.31],
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

nickel = {
    '2θ (degrees)' : [44.47, 51.88, 76.45],
    'intensity' : [86664, 97260, 98732]
}
hhgm_al = {
    '2θ (degrees)' : [38.5,45.01,65.17,78.31],
    'intensity' : [88549, 94191, 77714, 96400]
}
nacl = {
    'Q (1/A)' : [2.27158,3.16287,4.47829,4.99938],
    'intensity' : [88008, 19140, 98858, 46248]
}

df_ni = pd.DataFrame(nickel)
df_al = pd.DataFrame(hhgm_al)
df_nacl = pd.DataFrame(nacl)

df_ni
# Out:
#    2θ (degrees)  intensity
# 0         44.47      86664
# 1         51.88      97260
# 2         76.45      98732

# %%
df_al
# Out:
#    2θ (degrees)  intensity
# 0         38.50      88549
# 1         45.01      94191
# 2         65.17      77714
# 3         78.31      96400

# %%
df_nacl
# Out:
#    Q (1/A)  intensity
# 0  2.27158      88008
# 1  3.16287      19140
# 2  4.47829      98858
# 3  4.99938      46248

# %%
wavelength = 1.5406e-10
df_nacl['2θ (rad)'] = np.arcsin(wavelength / (2 *df_nacl['Q (1/A)']))

# %%
df_nacl
# Out:
#    Q (1/A)  intensity      2θ (rad)
# 0  2.27158      88008  3.391032e-11
# 1  3.16287      19140  2.435446e-11
# 2  4.47829      98858  1.720076e-11
# 3  4.99938      46248  1.540791e-11

# %%
wavelength = 1.5406e-10
df_nacl['2θ (rad)'] = np.arcsin(wavelength / (2 *df_nacl['Q (1/A)'])*1e-10)

# %%
df_nacl
# Out:
#    Q (1/A)  intensity      2θ (rad)
# 0  2.27158      88008  3.391032e-21
# 1  3.16287      19140  2.435446e-21
# 2  4.47829      98858  1.720076e-21
# 3  4.99938      46248  1.540791e-21

# %%
wavelength = 1.5406e-10
df_nacl['2θ (rad)'] = np.arcsin(wavelength / (2 *df_nacl['Q (1/A)'])*1e10)

# %%
df_nacl
# Out:
#    Q (1/A)  intensity  2θ (rad)
# 0  2.27158      88008  0.345963
# 1  3.16287      19140  0.246019
# 2  4.47829      98858  0.172867
# 3  4.99938      46248  0.154695

# %%
df_nacl['2θ (degrees)'] = df_nacl['2θ (rad)'] * 180 /np.pi

# %%
df_nacl
# Out:
#    Q (1/A)  intensity  2θ (rad)  2θ (degrees)
# 0  2.27158      88008  0.345963     19.822244
# 1  3.16287      19140  0.246019     14.095842
# 2  4.47829      98858  0.172867      9.904567
# 3  4.99938      46248  0.154695      8.863391

# %%
df_nacl['d-spacing'] = 1/df_nacl['Q (1/A)']

# %%
df_nacl['d-spacing'] = 1/df_nacl['Q (1/A)']

# %%
df_nacl
# Out:
#    Q (1/A)  intensity  2θ (rad)  2θ (degrees)  d-spacing
# 0  2.27158      88008  0.345963     19.822244   0.440222
# 1  3.16287      19140  0.246019     14.095842   0.316169
# 2  4.47829      98858  0.172867      9.904567   0.223300
# 3  4.99938      46248  0.154695      8.863391   0.200025

# %%
df_ni
# Out:
#    2θ (degrees)  intensity
# 0         44.47      86664
# 1         51.88      97260
# 2         76.45      98732

# %%
df_ni['d-spacing (A)'] = 1.5406 / (2 * np.sin(df_ni['2θ (degrees)'] * (np.pi()/180)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_ni['d-spacing (A)'] = 1.5406 / (2 * np.sin(df_ni['2θ (degrees)'] * (np.pi()/180)))
#
# TypeError: 'float' object is not callable

# %%
df_ni['d-spacing (A)'] = 1.5406 / (2 * np.sin(df_ni['2θ (degrees)'] * (np.pi/180)))

# %%
df_ni
# Out:
#    2θ (degrees)  intensity  d-spacing (A)
# 0         44.47      86664       1.099587
# 1         51.88      97260       0.979129
# 2         76.45      98732       0.792355

# %%
df_al['d-spacing (A)'] = 1.5406 / (2 * np.sin(df_al['2θ (degrees)'] * (np.pi/180)))

# %%
df_al
# Out:
#    2θ (degrees)  intensity  d-spacing (A)
# 0         38.50      88549       1.237401
# 1         45.01      94191       1.089179
# 2         65.17      77714       0.848761
# 3         78.31      96400       0.786616

# %%
df_al['d-spacing (A)'] = 1.5406 / (2 * np.sin(df_al['2θ (degrees)'] * (np.pi/180)/2))

# %%
df_ni['d-spacing (A)'] = 1.5406 / (2 * np.sin(df_ni['2θ (degrees)'] * (np.pi/180)/2))

# %%
df_al
# Out:
#    2θ (degrees)  intensity  d-spacing (A)
# 0         38.50      88549       2.336433
# 1         45.01      94191       2.012467
# 2         65.17      77714       1.430322
# 3         78.31      96400       1.219948

# %%
df_ni
# Out:
#    2θ (degrees)  intensity  d-spacing (A)
# 0         44.47      86664       2.035643
# 1         51.88      97260       1.760969
# 2         76.45      98732       1.244927

# %%
df_nacl
# Out:
#    Q (1/A)  intensity  2θ (rad)  2θ (degrees)  d-spacing
# 0  2.27158      88008  0.345963     19.822244   0.440222
# 1  3.16287      19140  0.246019     14.095842   0.316169
# 2  4.47829      98858  0.172867      9.904567   0.223300
# 3  4.99938      46248  0.154695      8.863391   0.200025

# %%
df_nacl['2θ (degrees)'] *= 2

# %%
df_nacl['2θ (rad)'] *= 2

# %%
df_nacl
# Out:
#    Q (1/A)  intensity  2θ (rad)  2θ (degrees)  d-spacing
# 0  2.27158      88008  0.691927     39.644489   0.440222
# 1  3.16287      19140  0.492038     28.191684   0.316169
# 2  4.47829      98858  0.345735     19.809134   0.223300
# 3  4.99938      46248  0.309391     17.726783   0.200025

# %%
wavelength = 1.5406e-10
df_nacl['2θ (rad)'] = 2 *np.arcsin(wavelength *df_nacl['Q (1/A)'])/ (2 *1e10)

# %%
df_nacl
# Out:
#    Q (1/A)  intensity      2θ (rad)  2θ (degrees)  d-spacing
# 0  2.27158      88008  3.499596e-20     39.644489   0.440222
# 1  3.16287      19140  4.872718e-20     28.191684   0.316169
# 2  4.47829      98858  6.899254e-20     19.809134   0.223300
# 3  4.99938      46248  7.702045e-20     17.726783   0.200025

# %%
wavelength = 1.5406e-10
df_nacl['2θ (rad)'] = 2 *np.arcsin(wavelength *df_nacl['Q (1/A)'])/ (2 *1e-10)

# %%
df_nacl
# Out:
#    Q (1/A)  intensity  2θ (rad)  2θ (degrees)  d-spacing
# 0  2.27158      88008  3.499596     39.644489   0.440222
# 1  3.16287      19140  4.872718     28.191684   0.316169
# 2  4.47829      98858  6.899254     19.809134   0.223300
# 3  4.99938      46248  7.702045     17.726783   0.200025

# %%
df_nacl['2θ (degrees)'] = df_nacl['2θ (rad)'] * 180/np.pi

# %%
df_nacl
# Out:
#    Q (1/A)  intensity  2θ (rad)  2θ (degrees)  d-spacing
# 0  2.27158      88008  3.499596    200.512089   0.440222
# 1  3.16287      19140  4.872718    279.186149   0.316169
# 2  4.47829      98858  6.899254    395.298112   0.223300
# 3  4.99938      46248  7.702045    441.294662   0.200025

# %%
frames = [df_al, df_ni, df_nacl]
for frame in frames:
    frame['2θ (rad)'] = frame['2θ (degrees)'] * np.pi/180

# %%
df_nacl['d-spacing (A)'] = df_nacl['d-spacing']

# %%
frames = [df_al, df_ni, df_nacl]
for frame in frames:
    frame['2θ (rad)'] = frame['2θ (degrees)'] * np.pi/180
    frame['θ (rad)'] =  frame['2θ (rad)']/2
    frame['sin(θ)'] = np.sin(frame['θ (rad)'])
    frame['sin^2(θ)'] = frame['sin(θ)']**2
    frame['lambda^2/4d'] = wavelength**2 /(4 *frame['d-spacing (A)'] * 1e-10)

# %%
df_al
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         38.50      88549       2.336433  0.671952  0.335976  0.329691
# 1         45.01      94191       2.012467  0.785573  0.392786  0.382764
# 2         65.17      77714       1.430322  1.137431  0.568716  0.538550
# 3         78.31      96400       1.219948  1.366767  0.683384  0.631420
#
#    sin^2(θ)   lambda^2/4d
# 0  0.108696  2.539607e-11
# 1  0.146508  2.948432e-11
# 2  0.290036  4.148452e-11
# 3  0.398692  4.863832e-11

# %%
df_nacl
# Out:
#    Q (1/A)  intensity  2θ (rad)  2θ (degrees)  d-spacing  d-spacing (A)  \
# 0  2.27158      88008  3.499596    200.512089   0.440222       0.440222
# 1  3.16287      19140  4.872718    279.186149   0.316169       0.316169
# 2  4.47829      98858  6.899254    395.298112   0.223300       0.223300
# 3  4.99938      46248  7.702045    441.294662   0.200025       0.200025
#
#     θ (rad)    sin(θ)  sin^2(θ)   lambda^2/4d
# 0  1.749798  0.984022  0.968299  1.347869e-10
# 1  2.436359  0.648212  0.420179  1.876727e-10
# 2  3.449627 -0.303186  0.091922  2.657248e-10
# 3  3.851022 -0.651401  0.424324  2.966443e-10

# %%
df_ni
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         44.47      86664       2.035643  0.776148  0.388074  0.378406
# 1         51.88      97260       1.760969  0.905477  0.452738  0.437430
# 2         76.45      98732       1.244927  1.334304  0.667152  0.618751
#
#    sin^2(θ)   lambda^2/4d
# 0  0.143191  2.914864e-11
# 1  0.191345  3.369521e-11
# 2  0.382853  4.766241e-11

# %%
frames = [df_al, df_ni, df_nacl]
for frame in frames:
    frame['2θ (rad)'] = frame['2θ (degrees)'] * np.pi/180
    frame['θ (rad)'] =  frame['2θ (rad)']/2
    frame['sin(θ)'] = np.sin(frame['θ (rad)'])
    frame['sin^2(θ)'] = frame['sin(θ)']**2
    frame['lambda^2/4d^2'] = wavelength**2 /(4 *(frame['d-spacing (A)'] * 1e-10)**2)

# %%
df_ni
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         44.47      86664       2.035643  0.776148  0.388074  0.378406
# 1         51.88      97260       1.760969  0.905477  0.452738  0.437430
# 2         76.45      98732       1.244927  1.334304  0.667152  0.618751
#
#    sin^2(θ)   lambda^2/4d  lambda^2/4d^2
# 0  0.143191  2.914864e-11       0.143191
# 1  0.191345  3.369521e-11       0.191345
# 2  0.382853  4.766241e-11       0.382853

# %%
frames = [df_al, df_ni, df_nacl]
for frame in frames:
    frame['2θ (rad)'] = frame['2θ (degrees)'] * np.pi/180
    frame['θ (rad)'] =  frame['2θ (rad)']/2
    frame['sin(θ)'] = np.sin(frame['θ (rad)'])
    frame['sin^2(θ)'] = frame['sin(θ)']**2
    frame['lambda^2/4d^2'] = wavelength**2 /(4 *(frame['d-spacing (A)'] * 1e-10)**2)
    frame['s_index'] =frame['sin^2(θ)'] /frame['lambda^2/4d^2']

# %%
frame['s_index']
# Out:
# 0    0.316252
# 1    0.070787
# 2    0.007725
# 3    0.028612
# Name: s_index, dtype: float64

# %%
df_al
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         38.50      88549       2.336433  0.671952  0.335976  0.329691
# 1         45.01      94191       2.012467  0.785573  0.392786  0.382764
# 2         65.17      77714       1.430322  1.137431  0.568716  0.538550
# 3         78.31      96400       1.219948  1.366767  0.683384  0.631420
#
#    sin^2(θ)   lambda^2/4d  lambda^2/4d^2  s_index
# 0  0.108696  2.539607e-11       0.108696      1.0
# 1  0.146508  2.948432e-11       0.146508      1.0
# 2  0.290036  4.148452e-11       0.290036      1.0
# 3  0.398692  4.863832e-11       0.398692      1.0

# %%
frames = [df_al, df_ni, df_nacl]
for frame in frames:
    frame['2θ (rad)'] = frame['2θ (degrees)'] * np.pi/180
    frame['θ (rad)'] =  frame['2θ (rad)']/2
    frame['sin(θ)'] = np.sin(frame['θ (rad)'])
    frame['sin^2(θ)'] = frame['sin(θ)']**2
    frame['lambda^2/4d^2'] = wavelength**2 /(4 *(frame['d-spacing (A)'][0] * 1e-10)**2)
    frame['s_index'] =frame['sin^2(θ)'] /frame['lambda^2/4d^2']

# %%
df_al
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         38.50      88549       2.336433  0.671952  0.335976  0.329691
# 1         45.01      94191       2.012467  0.785573  0.392786  0.382764
# 2         65.17      77714       1.430322  1.137431  0.568716  0.538550
# 3         78.31      96400       1.219948  1.366767  0.683384  0.631420
#
#    sin^2(θ)   lambda^2/4d  lambda^2/4d^2   s_index
# 0  0.108696  2.539607e-11       0.108696  1.000000
# 1  0.146508  2.948432e-11       0.108696  1.347873
# 2  0.290036  4.148452e-11       0.108696  2.668328
# 3  0.398692  4.863832e-11       0.108696  3.667956

# %%
df_nacl
# Out:
#    Q (1/A)  intensity  2θ (rad)  2θ (degrees)  d-spacing  d-spacing (A)  \
# 0  2.27158      88008  3.499596    200.512089   0.440222       0.440222
# 1  3.16287      19140  4.872718    279.186149   0.316169       0.316169
# 2  4.47829      98858  6.899254    395.298112   0.223300       0.223300
# 3  4.99938      46248  7.702045    441.294662   0.200025       0.200025
#
#     θ (rad)    sin(θ)  sin^2(θ)   lambda^2/4d  lambda^2/4d^2   s_index
# 0  1.749798  0.984022  0.968299  1.347869e-10       3.061793  0.316252
# 1  2.436359  0.648212  0.420179  1.876727e-10       3.061793  0.137233
# 2  3.449627 -0.303186  0.091922  2.657248e-10       3.061793  0.030022
# 3  3.851022 -0.651401  0.424324  2.966443e-10       3.061793  0.138587

# %%
df_ni
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         44.47      86664       2.035643  0.776148  0.388074  0.378406
# 1         51.88      97260       1.760969  0.905477  0.452738  0.437430
# 2         76.45      98732       1.244927  1.334304  0.667152  0.618751
#
#    sin^2(θ)   lambda^2/4d  lambda^2/4d^2   s_index
# 0  0.143191  2.914864e-11       0.143191  1.000000
# 1  0.191345  3.369521e-11       0.143191  1.336287
# 2  0.382853  4.766241e-11       0.143191  2.673717

# %%
df_ni['s_index'] *= 2

# %%
df_nacl['s_index'] *= 3

# %%
df_al['s_index'] *= 2

# %%
df_al
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         38.50      88549       2.336433  0.671952  0.335976  0.329691
# 1         45.01      94191       2.012467  0.785573  0.392786  0.382764
# 2         65.17      77714       1.430322  1.137431  0.568716  0.538550
# 3         78.31      96400       1.219948  1.366767  0.683384  0.631420
#
#    sin^2(θ)   lambda^2/4d  lambda^2/4d^2   s_index
# 0  0.108696  2.539607e-11       0.108696  2.000000
# 1  0.146508  2.948432e-11       0.108696  2.695746
# 2  0.290036  4.148452e-11       0.108696  5.336655
# 3  0.398692  4.863832e-11       0.108696  7.335911

# %%
df_ni
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         44.47      86664       2.035643  0.776148  0.388074  0.378406
# 1         51.88      97260       1.760969  0.905477  0.452738  0.437430
# 2         76.45      98732       1.244927  1.334304  0.667152  0.618751
#
#    sin^2(θ)   lambda^2/4d  lambda^2/4d^2   s_index
# 0  0.143191  2.914864e-11       0.143191  2.000000
# 1  0.191345  3.369521e-11       0.143191  2.672574
# 2  0.382853  4.766241e-11       0.143191  5.347434

# %%
df_nacl
# Out:
#    Q (1/A)  intensity  2θ (rad)  2θ (degrees)  d-spacing  d-spacing (A)  \
# 0  2.27158      88008  3.499596    200.512089   0.440222       0.440222
# 1  3.16287      19140  4.872718    279.186149   0.316169       0.316169
# 2  4.47829      98858  6.899254    395.298112   0.223300       0.223300
# 3  4.99938      46248  7.702045    441.294662   0.200025       0.200025
#
#     θ (rad)    sin(θ)  sin^2(θ)   lambda^2/4d  lambda^2/4d^2   s_index
# 0  1.749798  0.984022  0.968299  1.347869e-10       3.061793  0.948757
# 1  2.436359  0.648212  0.420179  1.876727e-10       3.061793  0.411699
# 2  3.449627 -0.303186  0.091922  2.657248e-10       3.061793  0.090067
# 3  3.851022 -0.651401  0.424324  2.966443e-10       3.061793  0.415760

# %%
df_al['s_index'] *=1.5
df_ni['s_index'] *=1.5

# %%
df_ni
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         44.47      86664       2.035643  0.776148  0.388074  0.378406
# 1         51.88      97260       1.760969  0.905477  0.452738  0.437430
# 2         76.45      98732       1.244927  1.334304  0.667152  0.618751
#
#    sin^2(θ)   lambda^2/4d  lambda^2/4d^2   s_index
# 0  0.143191  2.914864e-11       0.143191  3.000000
# 1  0.191345  3.369521e-11       0.143191  4.008862
# 2  0.382853  4.766241e-11       0.143191  8.021151

# %%
df_al
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         38.50      88549       2.336433  0.671952  0.335976  0.329691
# 1         45.01      94191       2.012467  0.785573  0.392786  0.382764
# 2         65.17      77714       1.430322  1.137431  0.568716  0.538550
# 3         78.31      96400       1.219948  1.366767  0.683384  0.631420
#
#    sin^2(θ)   lambda^2/4d  lambda^2/4d^2    s_index
# 0  0.108696  2.539607e-11       0.108696   3.000000
# 1  0.146508  2.948432e-11       0.108696   4.043620
# 2  0.290036  4.148452e-11       0.108696   8.004983
# 3  0.398692  4.863832e-11       0.108696  11.003867

# %%
df_nacl
# Out:
#    Q (1/A)  intensity  2θ (rad)  2θ (degrees)  d-spacing  d-spacing (A)  \
# 0  2.27158      88008  3.499596    200.512089   0.440222       0.440222
# 1  3.16287      19140  4.872718    279.186149   0.316169       0.316169
# 2  4.47829      98858  6.899254    395.298112   0.223300       0.223300
# 3  4.99938      46248  7.702045    441.294662   0.200025       0.200025
#
#     θ (rad)    sin(θ)  sin^2(θ)   lambda^2/4d  lambda^2/4d^2   s_index
# 0  1.749798  0.984022  0.968299  1.347869e-10       3.061793  0.948757
# 1  2.436359  0.648212  0.420179  1.876727e-10       3.061793  0.411699
# 2  3.449627 -0.303186  0.091922  2.657248e-10       3.061793  0.090067
# 3  3.851022 -0.651401  0.424324  2.966443e-10       3.061793  0.415760

# %%
for frame in frames:
    del frame['lambda^2/4d']

# %%
df_nacl
# Out:
#    Q (1/A)  intensity  2θ (rad)  2θ (degrees)  d-spacing  d-spacing (A)  \
# 0  2.27158      88008  3.499596    200.512089   0.440222       0.440222
# 1  3.16287      19140  4.872718    279.186149   0.316169       0.316169
# 2  4.47829      98858  6.899254    395.298112   0.223300       0.223300
# 3  4.99938      46248  7.702045    441.294662   0.200025       0.200025
#
#     θ (rad)    sin(θ)  sin^2(θ)  lambda^2/4d^2   s_index
# 0  1.749798  0.984022  0.968299       3.061793  0.948757
# 1  2.436359  0.648212  0.420179       3.061793  0.411699
# 2  3.449627 -0.303186  0.091922       3.061793  0.090067
# 3  3.851022 -0.651401  0.424324       3.061793  0.415760

# %%
df_ni
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         44.47      86664       2.035643  0.776148  0.388074  0.378406
# 1         51.88      97260       1.760969  0.905477  0.452738  0.437430
# 2         76.45      98732       1.244927  1.334304  0.667152  0.618751
#
#    sin^2(θ)  lambda^2/4d^2   s_index
# 0  0.143191       0.143191  3.000000
# 1  0.191345       0.143191  4.008862
# 2  0.382853       0.143191  8.021151

# %%
df_al
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         38.50      88549       2.336433  0.671952  0.335976  0.329691
# 1         45.01      94191       2.012467  0.785573  0.392786  0.382764
# 2         65.17      77714       1.430322  1.137431  0.568716  0.538550
# 3         78.31      96400       1.219948  1.366767  0.683384  0.631420
#
#    sin^2(θ)  lambda^2/4d^2    s_index
# 0  0.108696       0.108696   3.000000
# 1  0.146508       0.108696   4.043620
# 2  0.290036       0.108696   8.004983
# 3  0.398692       0.108696  11.003867

# %%
df_ni['a_0'] = df_ni['d-spacing (A)']/np.sqrt(df_ni['s_index'])

# %%
df_ni
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         44.47      86664       2.035643  0.776148  0.388074  0.378406
# 1         51.88      97260       1.760969  0.905477  0.452738  0.437430
# 2         76.45      98732       1.244927  1.334304  0.667152  0.618751
#
#    sin^2(θ)  lambda^2/4d^2   s_index       a_0
# 0  0.143191       0.143191  3.000000  1.175279
# 1  0.191345       0.143191  4.008862  0.879511
# 2  0.382853       0.143191  8.021151  0.439567

# %%
df_ni['a_0'] = df_ni['d-spacing (A)']*np.sqrt(df_ni['s_index'])

# %%
df_ni
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         44.47      86664       2.035643  0.776148  0.388074  0.378406
# 1         51.88      97260       1.760969  0.905477  0.452738  0.437430
# 2         76.45      98732       1.244927  1.334304  0.667152  0.618751
#
#    sin^2(θ)  lambda^2/4d^2   s_index       a_0
# 0  0.143191       0.143191  3.000000  3.525836
# 1  0.191345       0.143191  4.008862  3.525836
# 2  0.382853       0.143191  8.021151  3.525836

# %%
df_al['a_0'] = df_al['d-spacing (A)']*np.sqrt(df_ni['s_index'])

# %%
df_nacl['a_0'] = df_nacl['d-spacing (A)']*np.sqrt(df_ni['s_index'])

# %%
df_al
# Out:
#    2θ (degrees)  intensity  d-spacing (A)  2θ (rad)   θ (rad)    sin(θ)  \
# 0         38.50      88549       2.336433  0.671952  0.335976  0.329691
# 1         45.01      94191       2.012467  0.785573  0.392786  0.382764
# 2         65.17      77714       1.430322  1.137431  0.568716  0.538550
# 3         78.31      96400       1.219948  1.366767  0.683384  0.631420
#
#    sin^2(θ)  lambda^2/4d^2    s_index       a_0
# 0  0.108696       0.108696   3.000000  4.046820
# 1  0.146508       0.108696   4.043620  4.029390
# 2  0.290036       0.108696   8.004983  4.050905
# 3  0.398692       0.108696  11.003867       NaN

# %%
df_al['a_0'] = df_al['d-spacing (A)']*np.sqrt(df_al['s_index'])

# %%
df_nacl['a_0'] = df_nacl['d-spacing (A)']*np.sqrt(df_nacl['s_index'])
