# %%
import sklearn

# %%
# okay, we've got a 2 hour overview on scikit learn
# I'm gonna go through it all tonight.
# I'll put it on 1.5 and try to get through it by 11
# I'll have to put off research work until tomorrow
# is this the right choice?

# %%
# I can't focus on less interesting stuff rn
# this does need to be done.
# it's useful for this, but it's also less critical than the other stuff
# remember yesterday

# %%
# yeah, but I'm just really tired. the other stuff seems dreadful
# I don't know. I guess I just drank coffee
# but I think I'd rather have a few hours in a row to work
# on the other ones

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("drawndata1.csv")

# %%
df.head(3)
# Out:
#             x           y  z
# 0   58.080365  225.699042  a
# 1  238.867357  247.456645  a
# 2  156.218212  286.588782  a

# %%
X = df[['x','y']].values
y = df['z'] == "a"

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %% [markdown]
# notice outliers and weird scaling.
# preprocessing will ensure numerical stability by addressing scaling issues.
#
# StandardScaler addresses this. for each column, checks mean and variance.
# x - mean(x) / sqrt(var)
# is how this is done.

# %%
pred = LogisticRegression().fit(X,y).predict(X)
plt.scatter(X[:,0],X[:,1],c=pred)

# %%
from sklearn.preprocessing import StandardScaler, QuantileTransformer
X_new = QuantileTransformer(n_quantiles=100).fit_transform(X)
plt.scatter(X_new[:,0],X_new[:,1],c=y)

# %% [markdown]
# note - axes are much more similar numerically after applying standard scaler
# but not perfect. Can we do better?
#
# can deal with outliers.
# can calculate quantiles of data and preprocess our model using quantiles. right.

# %% [markdown]
# oh yeah, that looks much better. strange.

# %% [markdown]
# I really like the predicted data visualization he uses, it looks beautiful.
# practically a heatmap.

# %%
df = pd.read_csv('drawndata2.csv')
X = df[['x','y']].values
y = df['z'] == 'a'
plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline([
    ("scale" , QuantileTransformer(n_quantiles=100)),
    ("model" , LogisticRegression())
])

pred = pipe.fit(X,y).predict(X)
plt.scatter(X[:,0],X[:,1],c=pred)

# %% [markdown]
# clearly the logistic regression is qualitatively wrong.
# can this be fixed with linear regression?
#
# can limit ourselves to linear features, but can also use nonlinear features...

# %%
pipe = Pipeline([
    ("scale",PolynomialFeatures()),
    ("model",LogisticRegression())
])

pred = pipe.fit(X,y).predict(X)
plt.scatter(X[:,0],X[:,1],c=pred)

# %% [markdown]
# oh wow it practically works perfectly.
# I don't completely understand what it's doing, but that's quite interesting

# %%
# numeric encoder:

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
arr = np.array(["low","med","high","low"]).reshape(-1,1)
arr
# Out:
# array([['low'],
#        ['med'],
#        ['high'],
#        ['low']], dtype='<U4')

# %%
enc = OneHotEncoder()
print(np.array(enc.fit_transform(arr)))
# Out:
#   (0, 1)	1.0
#   (1, 2)	1.0
#   (2, 0)	1.0
#   (3, 1)	1.0

# %% [markdown]
# # Metrics

# %% [markdown]
# want to pick the best model frfr
